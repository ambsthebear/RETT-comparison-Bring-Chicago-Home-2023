# %% [markdown]
# ## Comparing RETT data across cities

# %%
import pandas as pd
import matplotlib as plt
RETT_info_df = pd.read_csv("RETT Numbers - Sheet1.csv")
print(RETT_info_df)
# Out:
#                          City  Amount of Sale in Millions (USD)
# 0           Chicago (current)                                 1  \
# 1           Chicago (current)                                 5
# 2           Chicago (current)                                10
# 3           Chicago (current)                                15
# 4   Chicago (with BCH passed)                                 1
# 5   Chicago (with BCH passed)                                 5
# 6   Chicago (with BCH passed)                                10
# 7   Chicago (with BCH passed)                                15
# 8               New York City                                 1
# 9               New York City                                 5
# 10              New York City                                10
# 11              New York City                                15
# 12                Los Angeles                                 1
# 13                Los Angeles                                 5
# ...

# %%
RETT_info_df.groupby(["Amount of Sale in Millions (USD)", "City"]).size().unstack().plot(kind="bar")
# Out:
# <Axes: xlabel='Amount of Sale in Millions (USD)'>
